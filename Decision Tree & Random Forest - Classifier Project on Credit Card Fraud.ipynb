# %% [markdown]
# # Steps
#
# 1. Import libraries
# 2. Import the Dataset
# 3. Perform the Data Analysis (DM, DC, DE, DV, EDA)
# 4. Data Preprocessing - Feature Engineering (Encoders, Scaling, Feature Importance/Selection, Hyper Parameter Tuning, etc.)
# 5. Spliting of data into sets - CV
# 6. Model Selection
# 7. Train the model
# 8. Test the model
# 9. Performance metric - Confusion matrix, accuracy_score

# %% [markdown]
#  ### Try to watch pandas profiling tool for dataset

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import seaborn as sns
from sklearn.model_selection import KFold,StratifiedKFold, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier

# Ensemble -  Ensemble means the collection of the models
# ExtraTreesClassifier - It helps to find the important features of the model

# %% [markdown]
# # Importing the dataset
#
# Link: "https://drive.google.com/file/d/1Q-gkb2MTSiRxn_MLoLHIA4AmRsGJ5Aiv/view?usp=sharing"
#
# * Download the file from here and then give location to pd.read_csv file
#
#
# #### Highly Imbalanced Dataset :- Highly Imbalanced Dataset means the data is not perticulary order. Suppose, In dataset starting 70% dataset has the approx value from 1900 to 2000 and we take that data as training model and then if the testing model has so much different values like 2200 to 2300, then in test time, It will predict always wrong. so, for that reason, it is known as highly imbalanced data.

# %%
df=pd.read_csv("C:/Users/Hello/Desktop/creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.Class.value_counts() 
#<- This is a highly imbalanced data because here, class 0 are in so many numbers where as class 1 has very few numbers. If, we get only one same class data in training model, then it will predict every time 0 as class value.
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# #### Here, we are using StratifiedKfold for train data, bcoz it will equally devide all traub dataset as per their quantity in train model

# %%
plt.figure(figsize=(50,50))
sns.heatmap(df.corr(),annot=True,cmap="Greens")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Here, there are 28 different features(columns), so from that we will take 18 to 20 features(columns) which has highly impact on class(target) value. It will help us to train the model easily. That's why we will use feature importance method for find the high impact features(columns)

# %% [markdown]
# # Feature Importance/ Selection

# %%
x= df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
model = ExtraTreesClassifier()

# %%
model.fit(x,y)
# Out:
# ExtraTreesClassifier()

# %%
model.feature_importances_
# Out:
# array([0.01599646, 0.01211611, 0.01377735, 0.03258102, 0.03112798,
#        0.01325558, 0.0142602 , 0.02377555, 0.01414205, 0.02994487,
#        0.06981996, 0.08148335, 0.10102384, 0.01154969, 0.13481761,
#        0.01220536, 0.06778488, 0.13155935, 0.04562196, 0.01550061,
#        0.01331631, 0.01656921, 0.01321752, 0.00920112, 0.012695  ,
#        0.0100893 , 0.01431491, 0.01415077, 0.01189536, 0.01220676])

# %%
plt.figure(figsize=(20,20))
feat=pd.Series(model.feature_importances_,index=x.columns)
feat.nlargest(18).plot(kind="barh")
plt.grid()

# %% [markdown]
# ### Here, we try to use both method one with  all 28 features(columns) and another with 18 highest impact features and will find accuracy for both for conclude that which will give the highest acuraccy.

# %%
feat=pd.Series(model.feature_importances_,index=x.columns)
plots=feat.nlargest(18)

# %%
plots.index
# Out:
# Index(['V14', 'V17', 'V12', 'V11', 'V10', 'V16', 'V18', 'V3', 'V4', 'V9', 'V7',
#        'V21', 'Time', 'V19', 'V26', 'V6', 'V27', 'V8'],
#       dtype='object')

# %%
x_new=df[plots.index]

# %%
x
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
x.shape   #<- x is a with all features(columns)
# Out:
# (284807, 30)

# %%
x_new.shape  #<- x_new is with top 18 highest impacted features
# Out:
# (284807, 18)

# %% [markdown]
# # Spliting the data into sets

# %%
skf = StratifiedKFold(n_splits=10)

# %%
for train_index,test_index in skf.split(x,y):
    x_train,x_test = x.iloc[train_index],x.iloc[test_index]
    y_train,y_test = y.iloc[train_index],y.iloc[test_index]

# %%
x_train.shape
# Out:
# (256327, 30)

# %%
for train_index,test_index in skf.split(x_new,y):
    x_new_train,x_new_test = x_new.iloc[train_index],x_new.iloc[test_index]
    y_new_train,y_new_test = y.iloc[train_index],y.iloc[test_index]

# %%
x_new.shape
# Out:
# (284807, 18)

# %% [markdown]
# # Model selection

# %%
decision = DecisionTreeClassifier()
randomf = RandomForestClassifier()

# %% [markdown]
# # Hyper parameter tuning for RandomForestClassifier

# %%
n_estimators = [int(i) for i in np.linspace(100,1200,12)]
max_features = ['auto', 'sqrt']
max_depth = [int(i) for i in np.linspace(5,30,5)]
min_samples_split = [2,5,10,15,100]
min_samples_leaf = [1,2,5,10]

# %%
parameters = {
    'n_estimators':n_estimators,
    'max_features':max_features,
    'max_depth':max_depth,
    'min_samples_split':min_samples_split,
    'min_samples_leaf':min_samples_leaf
}

# %%
parameters
# Out:
# {'n_estimators': [100,
#   200,
#   300,
#   400,
#   500,
#   600,
#   700,
#   800,
#   900,
#   1000,
#   1100,
#   1200],
#  'max_features': ['auto', 'sqrt'],
#  'max_depth': [5, 11, 17, 23, 30],
#  'min_samples_split': [2, 5, 10, 15, 100],
#  'min_samples_leaf': [1, 2, 5, 10]}

# %%
rf_model=RandomizedSearchCV(estimator=randomf,param_distributions=parameters,scoring="neg_mean_squared_error",n_jobs=1,cv=5,verbose=2,random_state=42)

# %%
rf_model.fit(x_train,y_train)   #<- It will take a long time for run, that's why we have just interupted the kernel

# %%
randomf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=randomf.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9993328651685394
